# %% [markdown]
# <table class="ee-notebook-buttons" align="center">
#     <td><a target="_blank"  href="https://colab.research.google.com/github/ytarazona/scikit-eo/blob/main/examples/15_Clipping_an_image.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # **_<div class="alert alert-success"><font color='darkred'> Tutorials: 15 Clipping an image</font></div>_**

# %% [markdown]
# # 1.0 Libraries

# %% [markdown]
# To install ```scikit-eo``` and ```rasterio``` you can do it with the following line:

# %%
# !pip install scikeo rasterio

# %% [markdown]
# Libraries to be used:

# %%
import rasterio
import numpy as np
from scikeo.process import crop
import matplotlib.pyplot as plt

# %% [markdown]
# Connecting to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2.0 Image and shapefile

# %% [markdown]
# The image and the shapefile to be used can be downloaded [here](https://drive.google.com/drive/folders/1hCwsShGhEb2INmKRo1MMbfHAQqJjKnyE?usp=sharing):

# %%
# raster to be clipped
path_raster = r"F:\RepositoriosGitHub\scikit-eo-tutorials\data\09_crop/LC08_band5.tif"

# area of Interes -> shapefile
path_shp = r"F:\RepositoriosGitHub\scikit-eo-tutorials\data\09_crop\corte_aleatorio.shp"

# %% [markdown]
# The output path and the output name:

# %%
# Path where the image will be saved
output_path_raster = r"F:\RepositoriosGitHub\scikit-eo-tutorials\data\09_crop"
# The raster name
output_name = 'LC08_band5_clip.tif'

# %% [markdown]
# Applying the ```crop()``` function:

# %%
crop(image = path_raster, shp = path_shp, filename = output_name, filepath = output_path_raster)

# %% [markdown]
# Reading the images as array:

# %%
original_image = rasterio.open(path_raster).read()
original_image = np.moveaxis(original_image, 0, -1)

clip_image = rasterio.open(output_path_raster + '/' + output_name + '.tif').read()
clip_image = np.moveaxis(clip_image, 0, -1)

# %% [markdown]
# Let´s plot both the original image and the clipped:

# %%
# Let´s plot
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (15, 9))
axes[0].imshow(original_image, cmap = 'gray')
axes[0].set_title("Original raster")
axes[0].grid(False)

axes[1].imshow(clip_image, cmap = 'gray')
axes[1].set_title("Raster clipped")
axes[1].grid(False)
