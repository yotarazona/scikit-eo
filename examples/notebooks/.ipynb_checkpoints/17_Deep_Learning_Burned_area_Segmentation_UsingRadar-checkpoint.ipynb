# %% [markdown]
# <table class="ee-notebook-buttons" align="center">
#     <td><a target="_blank"  href="https://colab.research.google.com/github/yotarazona/scikit-eo/blob/main/examples/notebooks/17_Deep_Learning_Burned_area_Segmentation_UsingRadar.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # **_<div class="alert alert-success"><font color='darkred'> Tutorials: 17 Burned Area Mapping using Deep Learning</font></div>_**

# %% [markdown]
# # 1.0 Libraries

# %% [markdown]
# To install ```scikit-eo``` you can do it with the following line:

# %%
# !pip install rasterio scikeo gdown
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting scikeo
#   Downloading scikeo-0.2.43-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.8.3)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.2.1)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from scikeo) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from scikeo) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from scikeo) (0.13.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from scikeo) (0.14.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from scikeo) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scikeo) (1.16.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from scikeo) (8.4.2)
# Collecting dbfread (from scikeo)
#   Downloading dbfread-2.0.7-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting fiona (from scikeo)
#   Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from scikeo) (1.1.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from scikeo) (2.19.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->scikeo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->scikeo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->scikeo) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (11.3.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->scikeo) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->scikeo) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->scikeo) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scikeo) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scikeo) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->scikeo) (1.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->scikeo) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->scikeo) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->scikeo) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->scikeo) (0.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->scikeo) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->scikeo) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->scikeo) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->scikeo) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow->scikeo) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->scikeo) (0.1.2)
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 76.4 MB/s eta 0:00:00
# Downloading scikeo-0.2.43-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 4.2 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 68.9 MB/s eta 0:00:00
# Installing collected packages: dbfread, cligj, click-plugins, affine, rasterio, fiona, scikeo
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 dbfread-2.0.7 fiona-1.10.1 rasterio-1.4.3 scikeo-0.2.43

# %% [markdown]
# Libraries to be used:

# %%
import rasterio
import numpy as np
from scikeo.deeplearning import processing, trainUnet, predictRaster
from scikeo.plot import plotRGB
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# Connecting to Google Drive

# %%
# Connect to Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading dataset directly from the external server (Google Drive in this case). To do this, ```gdown``` and ```zipfile``` will be installed before. Then you will only need to run the following line:

# %%
import gdown, zipfile

# Google Drive direct link
file_id = "1LaZ1QdXTtkDVAEtjpqylYOw1gebayEjJ"
url = f"https://drive.google.com/uc?id={file_id}"

# Define path in Drive
output_path = "/content/drive/MyDrive/11_deepLearning.zip"

# Download from Google Drive link
gdown.download(url, output_path, quiet=False)

# Extract inside your Drive
with zipfile.ZipFile(output_path, "r") as zip_ref:
    zip_ref.extractall("/content/drive/MyDrive")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1LaZ1QdXTtkDVAEtjpqylYOw1gebayEjJ
# From (redirected): https://drive.google.com/uc?id=1LaZ1QdXTtkDVAEtjpqylYOw1gebayEjJ&confirm=t&uuid=fc6518ad-34c5-4647-9416-35fa683d9a3e
# To: /content/drive/MyDrive/11_deepLearning.zip
# 100%|██████████| 506M/506M [00:10<00:00, 49.2MB/s]

# %% [markdown]
# ## 2.0 Satellite images

# %% [markdown]
# Sentinel-1 C-band will be used to classify burned and unburned areas using Deep Learning. This image contains two polarizations VV and VH which will be use to compute the Normalized Radar Burn Ratio (NRBR) ([Tarazona et al., 2025](https://ieeexplore.ieee.org/document/11096539)).
#
# Classes to be mapped are:
# - Unburned (pixel value 0)
# - Burned (pixel value 1)

# %%
data_dir = "/content/drive/MyDrive/11_deepLearning/11_deepLearning/"

## satellite image (NRBR)
# Tile29 for training/validation
path_raster_img = data_dir + "NRBR_Tile30.tif"
img_training = rasterio.open(path_raster_img)

# Tile30 for testing
path_raster_img_test = data_dir + "NRBR_Tile29.tif"
img_test = rasterio.open(path_raster_img_test)

# reference data
path_raster_label = data_dir + "Label_Tile30.tif"
label = rasterio.open(path_raster_label)

# %%
orig_map = plt.colormaps['Greys']
reversed_map = orig_map.reversed()

def preprocess_band(arr, pmin=15, pmax=85):
    """Replace NaN with zero and apply histogram stretch by percentiles."""
    # Replace NaN with 0
    arr = np.nan_to_num(arr, nan=0)
    # Apply histogram stretch
    low, high = np.nanpercentile(arr, pmin), np.nanpercentile(arr, pmax)
    arr = np.clip(arr, low, high)
    arr = (arr - low) / (high - low + 1e-6)  # normalize 0–1
    return arr.astype(np.float32)

img_training = preprocess_band(img_training.read(1))
label = label.read(1); label[np.isnan(label)] = 0
img_test = preprocess_band(img_test.read(1))

fig, ax = plt.subplots(1, 3, figsize = (15,9))
ax[0].imshow(img_training)
ax[0].set_title('Training: NRBR - Tile30')
ax[1].imshow(label, cmap = reversed_map)
ax[1].set_title('Training: Labeling data - Tile30')
ax[2].imshow(img_test)
ax[2].set_title('Testing: NRBR - Tile29')
plt.show()

# %% [markdown]
# ## 3.0 Burned area mapping

# %% [markdown]
# **Processing patches for training/validation**:
#
# In this step, patches (NRBR and Reference data patches) will be generated with the ```processing()``` function. Key arguments are
# - ```patch_size```: Por example, size of 128, 64, etc.
# - ```export_patches```: If True, NRBR patches will be exported in your local disc.
# - ```export_labels```: If True, Reference data patches will be exported in your local disc.
# - ```overlap```: Put a number if you wan to export overlaped patches.

# %%
# Step 1
X_patches, y_patches = processing(raster_path = path_raster_img,
                                  label_path = path_raster_label,
                                  patch_size = 256,
                                  export_patches = False,
                                  output_dir = None,
                                  export_labels = False,
                                  labels_output_dir = None,
                                  padding_mode = 'constant',
                                  padding_value = 0,
                                  overlap = 0)

# %%
# print basic details
print('Input features (NRBR) shape:', X_patches.shape)
print('\nInput labels shape:', y_patches.shape)
# Out:
# Input features (NRBR) shape: (520, 256, 256, 1)
#
# Input labels shape: (520, 256, 256, 1)

# %% [markdown]
# When you print the dimensions of the tensors, you will see:
#
# - `X_patches` has shape **(N, R, C, B)**, where:
#   - **N** = number of generated patches
#   - **R** = number of rows per patch
#   - **C** = number of columns per patch
#   - **B** = number of spectral bands (channels)
#
# - `y_patches` has shape **(N, R, C, 1)**, where the last dimension is always **1**, representing the label or class channel for each pixel in the patch.

# %% [markdown]
# **Preprocessing:**
#
# Before model training, the input patches were standardized using scikit-learn's ```StandardScaler()```, which applies Z-score normalization by centering the data (subtracting the mean) and scaling it by the standard deviation. This preprocessing step improves training stability and ensures better generalization across different geographic tiles.

# %% [markdown]
# **U-net architecture:**
#
# U-Net is a convolutional neural network architecture widely used for satellite image segmentation because of its ability to capture both spatial context and fine details. It follows an encoder–decoder structure: the encoder progressively downsamples the input to learn high-level features, while the decoder upsamples to reconstruct spatial resolution. Skip connections between corresponding encoder and decoder layers help preserve important spatial information, enabling precise boundary detection. This combination makes U-Net particularly effective for tasks like land cover classification, building extraction, and other remote sensing applications.
#
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2023/11/image-30.png" align="center" width="600"/>
#
# In this step, the U-Net model will be trained with the ```trainUnet()``` function. Key arguments are:
#
# - ```X_train```: Training image patchesX_patchesay).
# - ```y_train```: Training label patchey_patchesray).
# - ```input_shape```: Shape of the input patches, e.g., (128, 128, 1) for single-band or (128, 128, 3) for RGB.
# - ```num_classes```: Number of classes (1 for binary segment (e.g., burned and unburned)ation, n for multiclass).
# - ```normalize```: If `True`, applies normalization (StandardScaler) band by band.
# - ```dropout_rate```: Dropout probability for regularization (e.g., 0.2).
# - ```learning_rate```: Learning rate for the optimizer (e.g., 1e-3).
# - ```batch_size```: Number of patches per training batch.
# - ```epochs```: Number of training epochs.
# - ```validation_split```: Fraction of the data to use for validation (e.g., 0.1 for 10%).
# - ```validation_data```: Alternatively, provide a custom validation dataset instead of splitting.
# - ```save_best_model```: If `True`, saves the model with the best validation IoU score.
# - ```model_path```: File path where the best model will be saved (e.g., "/data/best_model.keras"), if not, put `None`

# %%
# Step 2: train with preprocessing
model, history = trainUnet(
    X_train=X_patches,
    y_train=y_patches,
    input_shape=(256, 256, 1),  # Depends on the number of bands
    num_classes=1,  # 1 for binary (burned and unburned), n for multiclass
    normalize=True,  # Normalize with StandardScaler
    dropout_rate=0.2,
    learning_rate=1e-3,
    batch_size=32,
    epochs=100,
    validation_split=0.3,   # use 10% (0.1) of the data for validation
    save_best_model=True,
    model_path= data_dir + '/' + 'best_model.keras'
)
# Out:
# 📊 Shape of X_train: (520, 256, 256, 1)
# 📊 Shape of y_train: (520, 256, 256, 1)
# 🎯 Number of classes: 1
# ✅ Null values replaced with 0 in X and y
# ✅ Normalization applied band by band with StandardScaler
# Values in labels, min: 0 & max: 1
# ✅ Split: 364 training, 156 validation
# 📊 Final X_train shape: (364, 256, 256, 1)
# 📊 Final y_train shape: (364, 256, 256, 1)
# 📊 Final X_val shape: (156, 256, 256, 1)
# 📊 Final y_val shape: (156, 256, 256, 1)
# ✅ Model compiled successfully (monitor: val_mean_iou)
# 💾 Saving best model based on val_mean_iou (max)
# 🚀 Starting training...
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.7709 - loss: 0.5477 - mean_iou: 0.2717
# Epoch 1: val_mean_iou improved from -inf to 0.41328, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.7757 - loss: 0.5396 - mean_iou: 0.2768 - val_accuracy: 0.9283 - val_loss: 0.2657 - val_mean_iou: 0.4133
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9269 - loss: 0.2466 - mean_iou: 0.4671
# Epoch 2: val_mean_iou improved from 0.41328 to 0.67576, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9274 - loss: 0.2448 - mean_iou: 0.4681 - val_accuracy: 0.9517 - val_loss: 0.2690 - val_mean_iou: 0.6758
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9442 - loss: 0.2059 - mean_iou: 0.5542
# Epoch 3: val_mean_iou did not improve from 0.67576
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9440 - loss: 0.2047 - mean_iou: 0.5520 - val_accuracy: 0.9425 - val_loss: 0.1396 - val_mean_iou: 0.5237
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9406 - loss: 0.1562 - mean_iou: 0.5406
# Epoch 4: val_mean_iou did not improve from 0.67576
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9408 - loss: 0.1561 - mean_iou: 0.5420 - val_accuracy: 0.9542 - val_loss: 0.1410 - val_mean_iou: 0.6391
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9506 - loss: 0.1379 - mean_iou: 0.5997
# Epoch 5: val_mean_iou did not improve from 0.67576
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9504 - loss: 0.1385 - mean_iou: 0.5991 - val_accuracy: 0.9557 - val_loss: 0.1207 - val_mean_iou: 0.6508
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9504 - loss: 0.1335 - mean_iou: 0.6572
# Epoch 6: val_mean_iou improved from 0.67576 to 0.70888, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9504 - loss: 0.1337 - mean_iou: 0.6586 - val_accuracy: 0.9593 - val_loss: 0.1180 - val_mean_iou: 0.7089
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9516 - loss: 0.1363 - mean_iou: 0.7160
# Epoch 7: val_mean_iou did not improve from 0.70888
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9519 - loss: 0.1356 - mean_iou: 0.7152 - val_accuracy: 0.9590 - val_loss: 0.1129 - val_mean_iou: 0.6880
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9582 - loss: 0.1177 - mean_iou: 0.6976
# Epoch 8: val_mean_iou improved from 0.70888 to 0.78013, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9580 - loss: 0.1181 - mean_iou: 0.6987 - val_accuracy: 0.9611 - val_loss: 0.1171 - val_mean_iou: 0.7801
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9566 - loss: 0.1248 - mean_iou: 0.7293
# Epoch 9: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9565 - loss: 0.1252 - mean_iou: 0.7291 - val_accuracy: 0.9606 - val_loss: 0.1335 - val_mean_iou: 0.7312
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9552 - loss: 0.1325 - mean_iou: 0.7165
# Epoch 10: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9553 - loss: 0.1319 - mean_iou: 0.7165 - val_accuracy: 0.9608 - val_loss: 0.1100 - val_mean_iou: 0.6951
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9548 - loss: 0.1257 - mean_iou: 0.7132
# Epoch 11: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9550 - loss: 0.1252 - mean_iou: 0.7137 - val_accuracy: 0.9616 - val_loss: 0.1030 - val_mean_iou: 0.7548
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9503 - loss: 0.1359 - mean_iou: 0.7256
# Epoch 12: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9508 - loss: 0.1347 - mean_iou: 0.7259 - val_accuracy: 0.9620 - val_loss: 0.1093 - val_mean_iou: 0.7421
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9595 - loss: 0.1136 - mean_iou: 0.7533
# Epoch 13: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9592 - loss: 0.1144 - mean_iou: 0.7506 - val_accuracy: 0.9618 - val_loss: 0.1087 - val_mean_iou: 0.7479
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9580 - loss: 0.1184 - mean_iou: 0.7446
# Epoch 14: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9578 - loss: 0.1191 - mean_iou: 0.7427 - val_accuracy: 0.9609 - val_loss: 0.1057 - val_mean_iou: 0.7098
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9525 - loss: 0.1302 - mean_iou: 0.6378
# Epoch 15: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9526 - loss: 0.1303 - mean_iou: 0.6395 - val_accuracy: 0.9584 - val_loss: 0.1119 - val_mean_iou: 0.7090
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9524 - loss: 0.1337 - mean_iou: 0.7015
# Epoch 16: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9526 - loss: 0.1330 - mean_iou: 0.7011 - val_accuracy: 0.9616 - val_loss: 0.1062 - val_mean_iou: 0.7469
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9570 - loss: 0.1169 - mean_iou: 0.7146
# Epoch 17: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9570 - loss: 0.1172 - mean_iou: 0.7131 - val_accuracy: 0.9613 - val_loss: 0.1115 - val_mean_iou: 0.6954
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9582 - loss: 0.1233 - mean_iou: 0.6984
# Epoch 18: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9580 - loss: 0.1233 - mean_iou: 0.7004 - val_accuracy: 0.9610 - val_loss: 0.1017 - val_mean_iou: 0.7770
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9623 - loss: 0.1011 - mean_iou: 0.7197
# Epoch 19: val_mean_iou did not improve from 0.78013
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9620 - loss: 0.1020 - mean_iou: 0.7214 - val_accuracy: 0.9617 - val_loss: 0.1002 - val_mean_iou: 0.7729
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9608 - loss: 0.1077 - mean_iou: 0.7814
# Epoch 20: val_mean_iou improved from 0.78013 to 0.78055, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9607 - loss: 0.1079 - mean_iou: 0.7820 - val_accuracy: 0.9622 - val_loss: 0.0987 - val_mean_iou: 0.7806
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9579 - loss: 0.1117 - mean_iou: 0.7956
# Epoch 21: val_mean_iou did not improve from 0.78055
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9581 - loss: 0.1113 - mean_iou: 0.7958 - val_accuracy: 0.9613 - val_loss: 0.1050 - val_mean_iou: 0.7683
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9576 - loss: 0.1169 - mean_iou: 0.7588
# Epoch 22: val_mean_iou improved from 0.78055 to 0.79513, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9577 - loss: 0.1164 - mean_iou: 0.7601 - val_accuracy: 0.9627 - val_loss: 0.1034 - val_mean_iou: 0.7951
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9575 - loss: 0.1177 - mean_iou: 0.7669
# Epoch 23: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9576 - loss: 0.1175 - mean_iou: 0.7666 - val_accuracy: 0.9625 - val_loss: 0.1017 - val_mean_iou: 0.7722
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9659 - loss: 0.0889 - mean_iou: 0.7840
# Epoch 24: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9655 - loss: 0.0902 - mean_iou: 0.7839 - val_accuracy: 0.9629 - val_loss: 0.1056 - val_mean_iou: 0.7820
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9569 - loss: 0.1179 - mean_iou: 0.7694
# Epoch 25: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9571 - loss: 0.1174 - mean_iou: 0.7710 - val_accuracy: 0.9619 - val_loss: 0.0986 - val_mean_iou: 0.7798
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9593 - loss: 0.1051 - mean_iou: 0.7839
# Epoch 26: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9593 - loss: 0.1054 - mean_iou: 0.7841 - val_accuracy: 0.9613 - val_loss: 0.1008 - val_mean_iou: 0.7316
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9608 - loss: 0.1084 - mean_iou: 0.7738
# Epoch 27: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9608 - loss: 0.1083 - mean_iou: 0.7747 - val_accuracy: 0.9623 - val_loss: 0.1030 - val_mean_iou: 0.7934
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9635 - loss: 0.0992 - mean_iou: 0.7965
# Epoch 28: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9633 - loss: 0.1000 - mean_iou: 0.7960 - val_accuracy: 0.9634 - val_loss: 0.0963 - val_mean_iou: 0.7379
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9587 - loss: 0.1109 - mean_iou: 0.7574
# Epoch 29: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9588 - loss: 0.1108 - mean_iou: 0.7588 - val_accuracy: 0.9639 - val_loss: 0.0956 - val_mean_iou: 0.7896
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9576 - loss: 0.1157 - mean_iou: 0.7914
# Epoch 30: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9579 - loss: 0.1147 - mean_iou: 0.7912 - val_accuracy: 0.9637 - val_loss: 0.0960 - val_mean_iou: 0.7857
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9571 - loss: 0.1139 - mean_iou: 0.7744
# Epoch 31: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9573 - loss: 0.1134 - mean_iou: 0.7757 - val_accuracy: 0.9649 - val_loss: 0.0931 - val_mean_iou: 0.7641
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9639 - loss: 0.0961 - mean_iou: 0.7828
# Epoch 32: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9638 - loss: 0.0966 - mean_iou: 0.7832 - val_accuracy: 0.9648 - val_loss: 0.0957 - val_mean_iou: 0.7660
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9628 - loss: 0.1015 - mean_iou: 0.7773
# Epoch 33: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9628 - loss: 0.1015 - mean_iou: 0.7782 - val_accuracy: 0.9653 - val_loss: 0.0923 - val_mean_iou: 0.7769
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9645 - loss: 0.0958 - mean_iou: 0.8006
# Epoch 34: val_mean_iou did not improve from 0.79513
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9642 - loss: 0.0962 - mean_iou: 0.8004 - val_accuracy: 0.9654 - val_loss: 0.0938 - val_mean_iou: 0.7734
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9650 - loss: 0.0941 - mean_iou: 0.8164
# Epoch 35: val_mean_iou improved from 0.79513 to 0.81268, saving model to /content/drive/MyDrive/11_deepLearning/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9649 - loss: 0.0945 - mean_iou: 0.8154 - val_accuracy: 0.9655 - val_loss: 0.1007 - val_mean_iou: 0.8127
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9601 - loss: 0.1078 - mean_iou: 0.7667
# Epoch 36: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9602 - loss: 0.1075 - mean_iou: 0.7680 - val_accuracy: 0.9652 - val_loss: 0.0928 - val_mean_iou: 0.7851
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9628 - loss: 0.1001 - mean_iou: 0.7898
# Epoch 37: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9627 - loss: 0.1005 - mean_iou: 0.7878 - val_accuracy: 0.9615 - val_loss: 0.0981 - val_mean_iou: 0.7640
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9631 - loss: 0.1018 - mean_iou: 0.7793
# Epoch 38: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9631 - loss: 0.1019 - mean_iou: 0.7792 - val_accuracy: 0.9652 - val_loss: 0.1077 - val_mean_iou: 0.8102
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9663 - loss: 0.0964 - mean_iou: 0.7879
# Epoch 39: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9662 - loss: 0.0965 - mean_iou: 0.7876 - val_accuracy: 0.9655 - val_loss: 0.0915 - val_mean_iou: 0.7953
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9673 - loss: 0.0907 - mean_iou: 0.8200
# Epoch 40: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9673 - loss: 0.0908 - mean_iou: 0.8188 - val_accuracy: 0.9664 - val_loss: 0.0900 - val_mean_iou: 0.7981
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9689 - loss: 0.0848 - mean_iou: 0.8090
# Epoch 41: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9687 - loss: 0.0852 - mean_iou: 0.8091 - val_accuracy: 0.9662 - val_loss: 0.0908 - val_mean_iou: 0.7955
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9681 - loss: 0.0895 - mean_iou: 0.7777
# Epoch 42: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9680 - loss: 0.0896 - mean_iou: 0.7775 - val_accuracy: 0.9666 - val_loss: 0.0903 - val_mean_iou: 0.7911
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9666 - loss: 0.0934 - mean_iou: 0.7997
# Epoch 43: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9667 - loss: 0.0930 - mean_iou: 0.7996 - val_accuracy: 0.9626 - val_loss: 0.0944 - val_mean_iou: 0.7431
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9711 - loss: 0.0781 - mean_iou: 0.7987
# Epoch 44: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9708 - loss: 0.0788 - mean_iou: 0.7980 - val_accuracy: 0.9615 - val_loss: 0.1124 - val_mean_iou: 0.7893
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9663 - loss: 0.0931 - mean_iou: 0.8111
# Epoch 45: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9664 - loss: 0.0928 - mean_iou: 0.8115 - val_accuracy: 0.9661 - val_loss: 0.0918 - val_mean_iou: 0.7968
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9690 - loss: 0.0844 - mean_iou: 0.8095
# Epoch 46: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9690 - loss: 0.0844 - mean_iou: 0.8104 - val_accuracy: 0.9658 - val_loss: 0.0904 - val_mean_iou: 0.7493
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9676 - loss: 0.0904 - mean_iou: 0.8110
# Epoch 47: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9678 - loss: 0.0898 - mean_iou: 0.8112 - val_accuracy: 0.9654 - val_loss: 0.0947 - val_mean_iou: 0.7724
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9681 - loss: 0.0849 - mean_iou: 0.7975
# Epoch 48: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9682 - loss: 0.0847 - mean_iou: 0.7974 - val_accuracy: 0.9667 - val_loss: 0.0928 - val_mean_iou: 0.7791
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9676 - loss: 0.0874 - mean_iou: 0.8161
# Epoch 49: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9679 - loss: 0.0867 - mean_iou: 0.8150 - val_accuracy: 0.9658 - val_loss: 0.0956 - val_mean_iou: 0.7559
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9723 - loss: 0.0747 - mean_iou: 0.8176
# Epoch 50: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9722 - loss: 0.0750 - mean_iou: 0.8175 - val_accuracy: 0.9655 - val_loss: 0.0937 - val_mean_iou: 0.7799
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9711 - loss: 0.0802 - mean_iou: 0.8128
# Epoch 51: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9710 - loss: 0.0803 - mean_iou: 0.8113 - val_accuracy: 0.9670 - val_loss: 0.1017 - val_mean_iou: 0.7956
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9713 - loss: 0.0799 - mean_iou: 0.8271
# Epoch 52: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9713 - loss: 0.0796 - mean_iou: 0.8261 - val_accuracy: 0.9665 - val_loss: 0.0958 - val_mean_iou: 0.7803
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9717 - loss: 0.0780 - mean_iou: 0.8307
# Epoch 53: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9718 - loss: 0.0776 - mean_iou: 0.8306 - val_accuracy: 0.9642 - val_loss: 0.1018 - val_mean_iou: 0.7819
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9774 - loss: 0.0632 - mean_iou: 0.8525
# Epoch 54: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9772 - loss: 0.0638 - mean_iou: 0.8507 - val_accuracy: 0.9637 - val_loss: 0.1019 - val_mean_iou: 0.7573
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9721 - loss: 0.0762 - mean_iou: 0.8365
# Epoch 55: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9722 - loss: 0.0761 - mean_iou: 0.8366 - val_accuracy: 0.9658 - val_loss: 0.1045 - val_mean_iou: 0.7821
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9745 - loss: 0.0689 - mean_iou: 0.8226
# Epoch 56: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9745 - loss: 0.0692 - mean_iou: 0.8224 - val_accuracy: 0.9637 - val_loss: 0.1008 - val_mean_iou: 0.7427
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9737 - loss: 0.0722 - mean_iou: 0.8396
# Epoch 57: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9738 - loss: 0.0719 - mean_iou: 0.8407 - val_accuracy: 0.9653 - val_loss: 0.1036 - val_mean_iou: 0.7738
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9769 - loss: 0.0638 - mean_iou: 0.8622
# Epoch 58: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9769 - loss: 0.0638 - mean_iou: 0.8617 - val_accuracy: 0.9652 - val_loss: 0.1126 - val_mean_iou: 0.7604
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9763 - loss: 0.0651 - mean_iou: 0.8452
# Epoch 59: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9763 - loss: 0.0651 - mean_iou: 0.8460 - val_accuracy: 0.9653 - val_loss: 0.0982 - val_mean_iou: 0.7271
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9746 - loss: 0.0686 - mean_iou: 0.7873
# Epoch 60: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9747 - loss: 0.0682 - mean_iou: 0.7891 - val_accuracy: 0.9647 - val_loss: 0.1175 - val_mean_iou: 0.7648
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9795 - loss: 0.0574 - mean_iou: 0.8687
# Epoch 61: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9794 - loss: 0.0576 - mean_iou: 0.8674 - val_accuracy: 0.9638 - val_loss: 0.1223 - val_mean_iou: 0.7463
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9795 - loss: 0.0560 - mean_iou: 0.8308
# Epoch 62: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9795 - loss: 0.0560 - mean_iou: 0.8318 - val_accuracy: 0.9628 - val_loss: 0.1181 - val_mean_iou: 0.7852
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9806 - loss: 0.0528 - mean_iou: 0.8693
# Epoch 63: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9806 - loss: 0.0529 - mean_iou: 0.8689 - val_accuracy: 0.9632 - val_loss: 0.1200 - val_mean_iou: 0.7417
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9815 - loss: 0.0517 - mean_iou: 0.8796
# Epoch 64: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9814 - loss: 0.0519 - mean_iou: 0.8777 - val_accuracy: 0.9621 - val_loss: 0.1272 - val_mean_iou: 0.7692
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9815 - loss: 0.0506 - mean_iou: 0.8589
# Epoch 65: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9815 - loss: 0.0507 - mean_iou: 0.8594 - val_accuracy: 0.9638 - val_loss: 0.1240 - val_mean_iou: 0.7708
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9816 - loss: 0.0504 - mean_iou: 0.8993
# Epoch 66: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9816 - loss: 0.0504 - mean_iou: 0.8985 - val_accuracy: 0.9626 - val_loss: 0.1276 - val_mean_iou: 0.7646
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9836 - loss: 0.0447 - mean_iou: 0.8907
# Epoch 67: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9835 - loss: 0.0450 - mean_iou: 0.8899 - val_accuracy: 0.9639 - val_loss: 0.1392 - val_mean_iou: 0.7587
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9819 - loss: 0.0504 - mean_iou: 0.8853
# Epoch 68: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9820 - loss: 0.0501 - mean_iou: 0.8849 - val_accuracy: 0.9645 - val_loss: 0.1283 - val_mean_iou: 0.7782
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9843 - loss: 0.0426 - mean_iou: 0.9127
# Epoch 69: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9843 - loss: 0.0427 - mean_iou: 0.9118 - val_accuracy: 0.9636 - val_loss: 0.1369 - val_mean_iou: 0.7460
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9846 - loss: 0.0424 - mean_iou: 0.8704
# Epoch 70: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9846 - loss: 0.0422 - mean_iou: 0.8713 - val_accuracy: 0.9629 - val_loss: 0.1340 - val_mean_iou: 0.7404
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9857 - loss: 0.0394 - mean_iou: 0.9140
# Epoch 71: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9857 - loss: 0.0395 - mean_iou: 0.9135 - val_accuracy: 0.9640 - val_loss: 0.1383 - val_mean_iou: 0.7651
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9861 - loss: 0.0379 - mean_iou: 0.9175
# Epoch 72: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9861 - loss: 0.0380 - mean_iou: 0.9165 - val_accuracy: 0.9636 - val_loss: 0.1402 - val_mean_iou: 0.7336
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9873 - loss: 0.0340 - mean_iou: 0.9000
# Epoch 73: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9872 - loss: 0.0343 - mean_iou: 0.8993 - val_accuracy: 0.9641 - val_loss: 0.1527 - val_mean_iou: 0.7665
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9860 - loss: 0.0378 - mean_iou: 0.9027
# Epoch 74: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9860 - loss: 0.0378 - mean_iou: 0.9026 - val_accuracy: 0.9640 - val_loss: 0.1407 - val_mean_iou: 0.7233
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9865 - loss: 0.0362 - mean_iou: 0.8858
# Epoch 75: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9864 - loss: 0.0363 - mean_iou: 0.8875 - val_accuracy: 0.9626 - val_loss: 0.1465 - val_mean_iou: 0.7362
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9859 - loss: 0.0376 - mean_iou: 0.9109
# Epoch 76: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9859 - loss: 0.0376 - mean_iou: 0.9092 - val_accuracy: 0.9637 - val_loss: 0.1448 - val_mean_iou: 0.7092
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9872 - loss: 0.0343 - mean_iou: 0.9001
# Epoch 77: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9872 - loss: 0.0343 - mean_iou: 0.8989 - val_accuracy: 0.9643 - val_loss: 0.1474 - val_mean_iou: 0.7463
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9875 - loss: 0.0341 - mean_iou: 0.9092
# Epoch 78: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9875 - loss: 0.0340 - mean_iou: 0.9092 - val_accuracy: 0.9631 - val_loss: 0.1562 - val_mean_iou: 0.7329
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9882 - loss: 0.0316 - mean_iou: 0.9389
# Epoch 79: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9882 - loss: 0.0317 - mean_iou: 0.9385 - val_accuracy: 0.9629 - val_loss: 0.1555 - val_mean_iou: 0.7286
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9900 - loss: 0.0270 - mean_iou: 0.9110
# Epoch 80: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9899 - loss: 0.0272 - mean_iou: 0.9117 - val_accuracy: 0.9638 - val_loss: 0.1599 - val_mean_iou: 0.7407
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9879 - loss: 0.0323 - mean_iou: 0.9370
# Epoch 81: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9880 - loss: 0.0321 - mean_iou: 0.9367 - val_accuracy: 0.9608 - val_loss: 0.1722 - val_mean_iou: 0.7299
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9876 - loss: 0.0334 - mean_iou: 0.9208
# Epoch 82: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9877 - loss: 0.0332 - mean_iou: 0.9207 - val_accuracy: 0.9620 - val_loss: 0.1839 - val_mean_iou: 0.7437
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9897 - loss: 0.0281 - mean_iou: 0.9297
# Epoch 83: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9896 - loss: 0.0281 - mean_iou: 0.9292 - val_accuracy: 0.9631 - val_loss: 0.1940 - val_mean_iou: 0.7572
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9898 - loss: 0.0273 - mean_iou: 0.9352
# Epoch 84: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9898 - loss: 0.0273 - mean_iou: 0.9353 - val_accuracy: 0.9632 - val_loss: 0.1719 - val_mean_iou: 0.7534
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9909 - loss: 0.0242 - mean_iou: 0.9388
# Epoch 85: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9909 - loss: 0.0243 - mean_iou: 0.9372 - val_accuracy: 0.9623 - val_loss: 0.1740 - val_mean_iou: 0.7601
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9894 - loss: 0.0286 - mean_iou: 0.9266
# Epoch 86: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9894 - loss: 0.0285 - mean_iou: 0.9262 - val_accuracy: 0.9635 - val_loss: 0.1671 - val_mean_iou: 0.7585
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9900 - loss: 0.0267 - mean_iou: 0.9400
# Epoch 87: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9901 - loss: 0.0266 - mean_iou: 0.9390 - val_accuracy: 0.9636 - val_loss: 0.1774 - val_mean_iou: 0.7445
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9912 - loss: 0.0230 - mean_iou: 0.9277
# Epoch 88: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9912 - loss: 0.0230 - mean_iou: 0.9278 - val_accuracy: 0.9639 - val_loss: 0.1953 - val_mean_iou: 0.7679
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9907 - loss: 0.0243 - mean_iou: 0.9570
# Epoch 89: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9907 - loss: 0.0243 - mean_iou: 0.9553 - val_accuracy: 0.9646 - val_loss: 0.1856 - val_mean_iou: 0.7610
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9918 - loss: 0.0216 - mean_iou: 0.9545
# Epoch 90: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.9918 - loss: 0.0218 - mean_iou: 0.9536 - val_accuracy: 0.9641 - val_loss: 0.2059 - val_mean_iou: 0.7620
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9914 - loss: 0.0226 - mean_iou: 0.9402
# Epoch 91: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9914 - loss: 0.0226 - mean_iou: 0.9405 - val_accuracy: 0.9638 - val_loss: 0.1933 - val_mean_iou: 0.7561
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9913 - loss: 0.0225 - mean_iou: 0.9510
# Epoch 92: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9913 - loss: 0.0225 - mean_iou: 0.9507 - val_accuracy: 0.9643 - val_loss: 0.1861 - val_mean_iou: 0.7570
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9918 - loss: 0.0217 - mean_iou: 0.9506
# Epoch 93: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9918 - loss: 0.0217 - mean_iou: 0.9502 - val_accuracy: 0.9642 - val_loss: 0.1950 - val_mean_iou: 0.7575
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9919 - loss: 0.0211 - mean_iou: 0.9449
# Epoch 94: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9919 - loss: 0.0211 - mean_iou: 0.9452 - val_accuracy: 0.9632 - val_loss: 0.2066 - val_mean_iou: 0.7588
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9921 - loss: 0.0206 - mean_iou: 0.9475
# Epoch 95: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9921 - loss: 0.0206 - mean_iou: 0.9473 - val_accuracy: 0.9622 - val_loss: 0.1999 - val_mean_iou: 0.7153
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9935 - loss: 0.0166 - mean_iou: 0.9282
# Epoch 96: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9934 - loss: 0.0169 - mean_iou: 0.9285 - val_accuracy: 0.9621 - val_loss: 0.1851 - val_mean_iou: 0.7452
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9929 - loss: 0.0187 - mean_iou: 0.9479
# Epoch 97: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9929 - loss: 0.0188 - mean_iou: 0.9478 - val_accuracy: 0.9633 - val_loss: 0.1938 - val_mean_iou: 0.7400
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9922 - loss: 0.0200 - mean_iou: 0.9445
# Epoch 98: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9923 - loss: 0.0199 - mean_iou: 0.9448 - val_accuracy: 0.9637 - val_loss: 0.2039 - val_mean_iou: 0.7442
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9925 - loss: 0.0193 - mean_iou: 0.9644
# Epoch 99: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - accuracy: 0.9925 - loss: 0.0192 - mean_iou: 0.9640 - val_accuracy: 0.9643 - val_loss: 0.2213 - val_mean_iou: 0.7647
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9932 - loss: 0.0174 - mean_iou: 0.9515
# Epoch 100: val_mean_iou did not improve from 0.81268
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.9932 - loss: 0.0174 - mean_iou: 0.9514 - val_accuracy: 0.9640 - val_loss: 0.2246 - val_mean_iou: 0.7632

# %%
# Print the available metrics and losses stored during training
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'mean_iou', 'val_accuracy', 'val_loss', 'val_mean_iou'])

# %% [markdown]
# This plot shows the training and validation performance of the U-Net model across epochs. The left panel illustrates the evolution of the loss function for both training and validation, which helps monitor overfitting or underfitting. The right panel displays the Mean IoU (Intersection over Union), a key segmentation metric, for training and validation, providing insights into how well the model learns to segment satellite images over time.

# %%
hist = history.history
epochs = range(1, len(hist['loss']) + 1)

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# --- Loss ---
ax[0].plot(epochs, hist['loss'], label='Training')
ax[0].plot(epochs, hist['val_loss'], label='Validation')
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend()

# --- IoU ---
ax[1].plot(epochs, hist['mean_iou'], label='Training')
ax[1].plot(epochs, hist['val_mean_iou'], label='Validation')
ax[1].set_title("Mean IoU")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("IoU")
ax[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Full prediction**
#
# In this step, we will predict on a new raster image using the trained U-Net model. Inside the `predictRaster()` function, the `processing()` function is used to divide the input raster into patches. After prediction, the patches are reconstructed back into a full raster mosaic with the same size and extent as the original image.
#
# **Key arguments**:
# - `raster_path`: Path to the input raster image (different from the training set or similar).
# - `patch_size`: Patch size used for prediction (must match training).
# - `num_classes`: Number of output classes (same as training).
# - `output_path`: Path to save the predicted raster (optional).
# - `fill_nulls`: If `True`, replaces null values with the value set in `null_value`.
# - `null_value`: Value used to replace missing or infinite values.
# - `normalize`: If `True`, applies the same normalization as during training.
# - `overlap`: Number of pixels to overlap between patches, useful for smoothing predictions.

# %%
# Step 3: Perform full prediction
prediction = predictRaster(
    model = model,
    raster_path = data_dir + '/'+ 'NRBR_Tile29.tif',
    patch_size = 256,  # Same as used during training
    num_classes = 1,   # Same as used during training
    output_path = data_dir + '/' + 'final_prediction.tif',  # Optional: save result
    fill_nulls = True,
    null_value = 0,
    normalize = True,
    overlap = 0,
)
# Out:
# Processing file: /content/drive/MyDrive/11_deepLearning/11_deepLearning//NRBR_Tile29.tif
# Handling null values...
# ✅ Normalization applied to X
# Running prediction...
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 7s 350ms/step
# Predicted classes: [0 1]
# Prediction saved at: /content/drive/MyDrive/11_deepLearning/11_deepLearning//prediccion_final.tif

# %% [markdown]
# Here we visualize the predicted burned area map alongside the NRBR index raster used as input for the model. This side-by-side comparison allows us to evaluate how the predicted segmentation relates to the original spectral information from the satellite image.

# %%
fig, ax = plt.subplots(1, 2, figsize = (12,6))

ax[0].imshow(img_test)
ax[0].set_title('Testing: NRBR - Tile30')
ax[1].imshow(prediction,cmap = reversed_map)
ax[1].set_title('Prediction on the whole image')
plt.show()
