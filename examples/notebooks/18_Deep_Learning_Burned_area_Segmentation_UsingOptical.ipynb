# %% [markdown]
# <table class="ee-notebook-buttons" align="center">
#     <td><a target="_blank"  href="https://colab.research.google.com/github/yotarazona/scikit-eo/blob/main/examples/notebooks/18_Deep_Learning_Burned_area_Segmentation_UsingOptical.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # **_<div class="alert alert-success"><font color='darkred'> Tutorials: 18 Burned Area Mapping using Deep Learning</font></div>_**

# %% [markdown]
# # 1.0 Libraries

# %% [markdown]
# To install ```scikit-eo``` you can do it with the following line:

# %%
# !pip install rasterio scikeo gdown
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting scikeo
#   Downloading scikeo-0.2.43-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.8.3)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.2.1)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from scikeo) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from scikeo) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from scikeo) (0.13.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from scikeo) (0.14.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from scikeo) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from scikeo) (1.16.2)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from scikeo) (8.4.2)
# Collecting dbfread (from scikeo)
#   Downloading dbfread-2.0.7-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting fiona (from scikeo)
#   Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from scikeo) (1.1.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (from scikeo) (2.19.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->scikeo) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->scikeo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->scikeo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->scikeo) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->scikeo) (11.3.0)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->scikeo) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->scikeo) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->scikeo) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scikeo) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->scikeo) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->scikeo) (1.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (1.75.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow->scikeo) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow->scikeo) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->scikeo) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->scikeo) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow->scikeo) (0.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->scikeo) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->scikeo) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow->scikeo) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->scikeo) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow->scikeo) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->scikeo) (0.1.2)
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 111.9 MB/s eta 0:00:00
# Downloading scikeo-0.2.43-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 4.8 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading dbfread-2.0.7-py2.py3-none-any.whl (20 kB)
# Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 25.3 MB/s eta 0:00:00
# Installing collected packages: dbfread, cligj, click-plugins, affine, rasterio, fiona, scikeo
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 dbfread-2.0.7 fiona-1.10.1 rasterio-1.4.3 scikeo-0.2.43

# %% [markdown]
# Libraries to be used:

# %%
import rasterio
import numpy as np
from scikeo.plot import plotRGB
from scikeo.deeplearning import processing, trainUnet, predictRaster
from scikeo.plot import plotRGB
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# Connecting to Google Drive

# %%
# Connect to Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading dataset directly from the external server (Google Drive in this case). To do this, ```gdown``` and ```zipfile``` will be installed before. Then you will only need to run the following line:

# %%
import gdown, zipfile

# Google Drive direct link
file_id = "1vN9Wzcdn2_sLcwNPrLyJ2M6iH7hiW0i7"
url = f"https://drive.google.com/uc?id={file_id}"

# Define path in Drive
output_path = "/content/drive/MyDrive/11_deepLearning.zip"

# Download from Google Drive link
gdown.download(url, output_path, quiet=False)

# Extract inside your Drive
with zipfile.ZipFile(output_path, "r") as zip_ref:
    zip_ref.extractall("/content/drive/MyDrive")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vN9Wzcdn2_sLcwNPrLyJ2M6iH7hiW0i7
# From (redirected): https://drive.google.com/uc?id=1vN9Wzcdn2_sLcwNPrLyJ2M6iH7hiW0i7&confirm=t&uuid=50f44dcd-8e2d-4b52-9990-0a447c5cacd8
# To: /content/drive/MyDrive/11_deepLearning.zip
# 100%|██████████| 2.32G/2.32G [00:57<00:00, 40.5MB/s]

# %% [markdown]
# ## 2.0 Satellite images

# %% [markdown]
# Sentinel-2 provides multispectral imagery across the visible, near-infrared, and shortwave infrared regions, which are widely applied in environmental monitoring and land classification. For training the U-net model, the following Surface Reflectance bands are used:
#
# - Blue (**B2**)
# - Green (**B3**)
# - Red (**B4**)
# - Red Edge 1 (**B5**)
# - Red Edge 2 (**B6**)
# - Red Edge 3 (**B7**)
# - Near Infrared (NIR, **B8**)
# - Red Edge 4 (**B8A**)
# - Shortwave Infrared 1 (SWIR 1, **B11**)
# - Shortwave Infrared 2 (SWIR 2, **B12**)
#
# Classes to be mapped are:
# - Unburned (pixel value 0)
# - Burned (pixel value 1)

# %%
data_dir = "/content/drive/MyDrive/11_deepLearning/"

## satellite image (NRBR)
# Tile29 for training/validation
path_raster_img = data_dir + "S2_Tile30.tif"
img_training = rasterio.open(path_raster_img)

# Tile30 for testing
path_raster_img_test = data_dir + "S2_Tile29.tif"
img_test = rasterio.open(path_raster_img_test)

# reference data
path_raster_label = data_dir + "Label_Tile30.tif"
label = rasterio.open(path_raster_label)

# %%
# number of bands
img_training.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float64',
#  'nodata': None,
#  'width': 6512,
#  'height': 5014,
#  'count': 10,
#  'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'),
#  'transform': Affine(8.983152841195215e-05, 0.0, -8.436438159280074,
#         0.0, -8.983152841195215e-05, 39.9193345957033)}

# %%
orig_map = plt.colormaps['Greys']
reversed_map = orig_map.reversed()

label = label.read(1); label[np.isnan(label)] = 0

fig, ax = plt.subplots(1, 3, figsize = (15,9))
plotRGB(img_training, bands = [10, 7, 3], title = 'Training: NRBR - Tile30', ax = ax[0])
ax[1].imshow(label, cmap = reversed_map)
ax[1].set_title('Training: Labeling data - Tile30')
plotRGB(img_test, bands = [10, 7, 3], title = 'Testing: NRBR - Tile29', ax = ax[2])
plt.show()

# %% [markdown]
# ## 3.0 Burned area mapping

# %% [markdown]
# **Processing patches for training/validation**:
#
# In this step, patches (NRBR and Reference data patches) will be generated with the ```processing()``` function. Key arguments are
# - ```patch_size```: Por example, size of 128, 64, etc.
# - ```export_patches```: If True, NRBR patches will be exported in your local disc.
# - ```export_labels```: If True, Reference data patches will be exported in your local disc.
# - ```overlap```: Put a number if you wan to export overlaped patches.

# %%
# Step 1
X_patches, y_patches = processing(raster_path = path_raster_img,
                                  label_path = path_raster_label,
                                  patch_size = 256,
                                  export_patches = False,
                                  output_dir = None,
                                  export_labels = False,
                                  labels_output_dir = None,
                                  padding_mode = 'constant',
                                  padding_value = 0,
                                  overlap = 0)

# %%
# print basic details
print('Input features (NRBR) shape:', X_patches.shape)
print('\nInput labels shape:', y_patches.shape)
# Out:
# Input features (NRBR) shape: (520, 256, 256, 10)
#
# Input labels shape: (520, 256, 256, 1)

# %% [markdown]
# When you print the dimensions of the tensors, you will see:
#
# - `X_patches` has shape **(N, R, C, B)**, where:
#   - **N** = number of generated patches
#   - **R** = number of rows per patch
#   - **C** = number of columns per patch
#   - **B** = number of spectral bands (channels)
#
# - `y_patches` has shape **(N, R, C, 1)**, where the last dimension is always **1**, representing the label or class channel for each pixel in the patch.

# %% [markdown]
# **Preprocessing:**
#
# Before model training, the input patches were standardized using scikit-learn's ```StandardScaler()```, which applies Z-score normalization by centering the data (subtracting the mean) and scaling it by the standard deviation. This preprocessing step improves training stability and ensures better generalization across different geographic tiles.

# %% [markdown]
# **U-net architecture:**
#
# U-Net is a convolutional neural network architecture widely used for satellite image segmentation because of its ability to capture both spatial context and fine details. It follows an encoder–decoder structure: the encoder progressively downsamples the input to learn high-level features, while the decoder upsamples to reconstruct spatial resolution. Skip connections between corresponding encoder and decoder layers help preserve important spatial information, enabling precise boundary detection. This combination makes U-Net particularly effective for tasks like land cover classification, building extraction, and other remote sensing applications.
#
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2023/11/image-30.png" align="center" width="600"/>
#
# In this step, the U-Net model will be trained with the ```trainUnet()``` function. Key arguments are:
#
# - ```X_train```: Training image patchesX_patchesay).
# - ```y_train```: Training label patchey_patchesray).
# - ```input_shape```: Shape of the input patches, e.g., (128, 128, 1) for single-band or (128, 128, 3) for RGB.
# - ```num_classes```: Number of classes (1 for binary segment (e.g., burned and unburned)ation, n for multiclass).
# - ```normalize```: If `True`, applies normalization (StandardScaler) band by band.
# - ```dropout_rate```: Dropout probability for regularization (e.g., 0.2).
# - ```learning_rate```: Learning rate for the optimizer (e.g., 1e-3).
# - ```batch_size```: Number of patches per training batch.
# - ```epochs```: Number of training epochs.
# - ```validation_split```: Fraction of the data to use for validation (e.g., 0.1 for 10%).
# - ```validation_data```: Alternatively, provide a custom validation dataset instead of splitting.
# - ```save_best_model```: If `True`, saves the model with the best validation IoU score.
# - ```model_path```: File path where the best model will be saved (e.g., "/data/best_model.keras"), if not, put `None`

# %%
# Step 2: train with preprocessing
model, history = trainUnet(
    X_train=X_patches,
    y_train=y_patches,
    input_shape=(256, 256, 10),  # Depends on the number of bands
    num_classes=1,  # 1 for binary (burned and unburned), n for multiclass
    normalize=True,  # Normalize with StandardScaler
    dropout_rate=0.2,
    learning_rate=1e-3,
    batch_size=32,
    epochs=100,
    validation_split=0.3,   # use 10% (0.1) of the data for validation
    save_best_model=True,
    model_path= data_dir + '/' + 'best_model.keras'
)
# Out:
# 📊 Shape of X_train: (520, 256, 256, 10)
# 📊 Shape of y_train: (520, 256, 256, 1)
# 🎯 Number of classes: 1
# ✅ Null values replaced with 0 in X and y
# ✅ Normalization applied band by band with StandardScaler
# Values in labels, min: 0 & max: 1
# ✅ Split: 364 training, 156 validation
# 📊 Final X_train shape: (364, 256, 256, 10)
# 📊 Final y_train shape: (364, 256, 256, 1)
# 📊 Final X_val shape: (156, 256, 256, 10)
# 📊 Final y_val shape: (156, 256, 256, 1)
# ✅ Model compiled successfully (monitor: val_mean_iou)
# 💾 Saving best model based on val_mean_iou (max)
# 🚀 Starting training...
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9877 - loss: 0.0318 - mean_iou: 0.9257
# Epoch 99: val_mean_iou did not improve from 0.88438
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9877 - loss: 0.0317 - mean_iou: 0.9265 - val_accuracy: 0.9725 - val_loss: 0.1126 - val_mean_iou: 0.8358
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9901 - loss: 0.0255 - mean_iou: 0.9393
# Epoch 100: val_mean_iou did not improve from 0.88438
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9900 - loss: 0.0258 - mean_iou: 0.9394 - val_accuracy: 0.9714 - val_loss: 0.1057 - val_mean_iou: 0.8510

# %%
# Print the available metrics and losses stored during training
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'mean_iou', 'val_accuracy', 'val_loss', 'val_mean_iou'])

# %% [markdown]
# This plot shows the training and validation performance of the U-Net model across epochs. The left panel illustrates the evolution of the loss function for both training and validation, which helps monitor overfitting or underfitting. The right panel displays the Mean IoU (Intersection over Union), a key segmentation metric, for training and validation, providing insights into how well the model learns to segment satellite images over time.

# %%
hist = history.history
epochs = range(1, len(hist['loss']) + 1)

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# --- Loss ---
ax[0].plot(epochs, hist['loss'], label='Training')
ax[0].plot(epochs, hist['val_loss'], label='Validation')
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend()

# --- IoU ---
ax[1].plot(epochs, hist['mean_iou'], label='Training')
ax[1].plot(epochs, hist['val_mean_iou'], label='Validation')
ax[1].set_title("Mean IoU")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("IoU")
ax[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Full prediction**
#
# In this step, we will predict on a new raster image using the trained U-Net model. Inside the `predictRaster()` function, the `processing()` function is used to divide the input raster into patches. After prediction, the patches are reconstructed back into a full raster mosaic with the same size and extent as the original image.
#
# **Key arguments**:
# - `raster_path`: Path to the input raster image (different from the training set or similar).
# - `patch_size`: Patch size used for prediction (must match training).
# - `num_classes`: Number of output classes (same as training).
# - `output_path`: Path to save the predicted raster (optional).
# - `fill_nulls`: If `True`, replaces null values with the value set in `null_value`.
# - `null_value`: Value used to replace missing or infinite values.
# - `normalize`: If `True`, applies the same normalization as during training.
# - `overlap`: Number of pixels to overlap between patches, useful for smoothing predictions.

# %%
# Step 3: Perform full prediction
prediction = predictRaster(
    model = model,
    raster_path = data_dir + '/' + 'S2_Tile29.tif',
    patch_size = 256,  # Same as used during training
    num_classes = 1,   # Same as used during training
    output_path = data_dir + '/' + 'final_prediction.tif',  # Optional: save result
    fill_nulls = True,
    null_value = 0,
    normalize = True,
    overlap = 0,
)
# Out:
# Processing file: /content/drive/MyDrive/11_deepLearning//S2_Tile29.tif
# Handling null values...
# ✅ Normalization applied to X
# Running prediction...
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 332ms/step
# Predicted classes: [0 1]
# Prediction saved at: /content/drive/MyDrive/11_deepLearning//prediccion_final.tif

# %% [markdown]
# Here we visualize the predicted burned area map alongside the NRBR index raster used as input for the model. This side-by-side comparison allows us to evaluate how the predicted segmentation relates to the original spectral information from the satellite image.

# %%
fig, ax = plt.subplots(1, 2, figsize = (12,6))

plotRGB(img_test, bands = [10, 7, 3], title = 'Testing: NRBR - Tile29', ax = ax[0])
ax[1].imshow(prediction,cmap = reversed_map)
ax[1].set_title('Prediction on the whole image')
plt.show()
