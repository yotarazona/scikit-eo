# %% [markdown]
# <table class="ee-notebook-buttons" align="center">
#     <td><a target="_blank"  href="https://colab.research.google.com/github/yotarazona/scikit-eo/blob/main/examples/notebooks/18_Deep_Learning_Burned_area_Segmentation_UsingOptical.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a></td>
# </table>

# %% [markdown]
# # **_<div class="alert alert-success"><font color='darkred'> Tutorials: 17 Burned Area Mapping using Deep Learning</font></div>_**

# %% [markdown]
# # 1.0 Libraries

# %% [markdown]
# To install ```scikit-eo``` you can do it with the following line:

# %%
# !pip install rasterio scikeo gdown

# %% [markdown]
# Libraries to be used:

# %%
import rasterio
import numpy as np
from scikeo.deeplearning import processing, trainUnet, predictRaster
from scikeo.deeplearning import evaluateSegmentation
from scikeo.plot import plotRGB
import matplotlib.pyplot as plt
import matplotlib as mpl

# %% [markdown]
# Connecting to Google Drive

# %%
# Connect to Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Reading dataset directly from the external server (Google Drive in this case). To do this, ```gdown``` and ```zipfile``` will be installed before. Then you will only need to run the following line:

# %%
import gdown, zipfile

# Google Drive direct link
file_id = "1vN9Wzcdn2_sLcwNPrLyJ2M6iH7hiW0i7"
url = f"https://drive.google.com/uc?id={file_id}"

# Define path in Drive
output_path = "/content/drive/MyDrive/11_deepLearning.zip"

# Download from Google Drive link
gdown.download(url, output_path, quiet=False)

# Extract inside your Drive
with zipfile.ZipFile(output_path, "r") as zip_ref:
    zip_ref.extractall("/content/drive/MyDrive")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1vN9Wzcdn2_sLcwNPrLyJ2M6iH7hiW0i7
# From (redirected): https://drive.google.com/uc?id=1vN9Wzcdn2_sLcwNPrLyJ2M6iH7hiW0i7&confirm=t&uuid=50f44dcd-8e2d-4b52-9990-0a447c5cacd8
# To: /content/drive/MyDrive/11_deepLearning.zip
# 100%|██████████| 2.32G/2.32G [00:57<00:00, 40.5MB/s]

# %% [markdown]
# ## 2.0 Satellite images

# %% [markdown]
# Sentinel-2 provides multispectral imagery across the visible, near-infrared, and shortwave infrared regions, which are widely applied in environmental monitoring and land classification. For training the U-net model, the following Surface Reflectance bands are used:
#
# - Blue (**B2**)
# - Green (**B3**)
# - Red (**B4**)
# - Red Edge 1 (**B5**)
# - Red Edge 2 (**B6**)
# - Red Edge 3 (**B7**)
# - Near Infrared (NIR, **B8**)
# - Red Edge 4 (**B8A**)
# - Shortwave Infrared 1 (SWIR 1, **B11**)
# - Shortwave Infrared 2 (SWIR 2, **B12**)
#
# Classes to be mapped are:
# - Unburned (pixel value 0)
# - Burned (pixel value 1)

# %%
data_dir = "/content/drive/MyDrive/11_deepLearning/"

## satellite image (NRBR)
## TRAINING/VALIDATION
# Til30
path_raster_img = data_dir + "S2_Tile30.tif"
img_training = rasterio.open(path_raster_img)
# reference data
path_raster_label = data_dir + "Label_Tile30.tif"
label = rasterio.open(path_raster_label)

## TESTING
# Tile29 for testing
path_raster_img_test = data_dir + "S2_Tile29.tif"
img_test = rasterio.open(path_raster_img_test)

# %%
# number of bands
img_training.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float64',
#  'nodata': None,
#  'width': 6512,
#  'height': 5014,
#  'count': 10,
#  'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'),
#  'transform': Affine(8.983152841195215e-05, 0.0, -8.436438159280074,
#         0.0, -8.983152841195215e-05, 39.9193345957033)}

# %%
orig_map = plt.colormaps['Greys']
reversed_map = orig_map.reversed()

label = label.read(1); label[np.isnan(label)] = 0

fig, ax = plt.subplots(1, 3, figsize = (15,9))
plotRGB(img_training, bands = [10, 7, 3], title = 'Training: Sentinel2 - Tile30', ax = ax[0])
ax[1].imshow(label, cmap = reversed_map)
ax[1].set_title('Training: Labeling data - Tile30')
plotRGB(img_test, bands = [10, 7, 3], title = 'Testing: Sentinel2 - Tile29', ax = ax[2])
plt.show()

# %% [markdown]
# ## 3.0 Burned area mapping

# %% [markdown]
# **Processing patches for training/validation**:
#
# In this step, patches (NRBR and Reference data patches) will be generated with the ```processing()``` function. Key arguments are
# - ```patch_size```: Por example, size of 128, 64, etc.
# - ```export_patches```: If True, NRBR patches will be exported in your local disc.
# - ```export_labels```: If True, Reference data patches will be exported in your local disc.
# - ```overlap```: Put a number if you wan to export overlaped patches.

# %%
# Step 1
X_patches, y_patches = processing(raster_path = path_raster_img,
                                  label_path = path_raster_label,
                                  patch_size = 256,
                                  export_patches = False,
                                  output_dir = None,
                                  export_labels = False,
                                  labels_output_dir = None,
                                  padding_mode = 'constant',
                                  padding_value = 0,
                                  overlap = 0)

# %%
# print basic details
print('Input features (NRBR) shape:', X_patches.shape)
print('\nInput labels shape:', y_patches.shape)
# Out:
# Input features (NRBR) shape: (520, 256, 256, 10)
#
# Input labels shape: (520, 256, 256, 1)

# %% [markdown]
# When you print the dimensions of the tensors, you will see:
#
# - `X_patches` has shape **(N, R, C, B)**, where:
#   - **N** = number of generated patches
#   - **R** = number of rows per patch
#   - **C** = number of columns per patch
#   - **B** = number of spectral bands (channels)
#
# - `y_patches` has shape **(N, R, C, 1)**, where the last dimension is always **1**, representing the label or class channel for each pixel in the patch.

# %% [markdown]
# **Preprocessing:**
#
# Before model training, the input patches were standardized using scikit-learn's ```StandardScaler()```, which applies Z-score normalization by centering the data (subtracting the mean) and scaling it by the standard deviation. This preprocessing step improves training stability and ensures better generalization across different geographic tiles.

# %% [markdown]
# **U-net architecture:**
#
# U-Net is a convolutional neural network architecture widely used for satellite image segmentation because of its ability to capture both spatial context and fine details. It follows an encoder–decoder structure: the encoder progressively downsamples the input to learn high-level features, while the decoder upsamples to reconstruct spatial resolution. Skip connections between corresponding encoder and decoder layers help preserve important spatial information, enabling precise boundary detection. This combination makes U-Net particularly effective for tasks like land cover classification, building extraction, and other remote sensing applications.
#
# <img src="https://cdn.analyticsvidhya.com/wp-content/uploads/2023/11/image-30.png" align="center" width="600"/>
#
# In this step, the U-Net model will be trained with the ```trainUnet()``` function. Key arguments are:
#
# - ```X_train```: Training image patches (X_patches).
# - ```y_train```: Training label patches (y_patches).
# - ```input_shape```: Shape of the input patches, e.g., (128, 128, 1) for single-band or (128, 128, 3) for RGB.
# - ```num_classes```: Number of classes (1 for binary segmentation (e.g., burned and unburned), n for multiclass).
# - ```normalize```: If `True`, applies normalization (StandardScaler) band by band.
# - ```dropout_rate```: Dropout probability for regularization (e.g., 0.2).
# - ```learning_rate```: Learning rate for the optimizer (e.g., 1e-3).
# - ```batch_size```: Number of patches per training batch.
# - ```epochs```: Number of training epochs.
# - ```validation_split```: Fraction of the data to use for validation (e.g., 0.1 for 10%).
# - ```data_augumentation```: If True, applies random flips and rotations for augmentation (default=False).
# - ```validation_data```: Alternatively, provide a custom validation dataset instead of splitting.
# - ```save_best_model```: If `True`, saves the model with the best validation IoU score.
# - ```model_path```: File path where the best model will be saved (e.g., "/data/best_model.keras"), if not, put `None`.

# %%
# Step 2: train with preprocessing
model, history = trainUnet(
    X_train=X_patches,
    y_train=y_patches,
    input_shape=(256, 256, 10),  # Depends on the number of bands
    num_classes=1,  # 1 for binary (burned and unburned), n for multiclass
    normalize=True,  # Normalize with StandardScaler
    dropout_rate=0.2,
    learning_rate=1e-3,
    batch_size=32,
    epochs=100,
    validation_split=0.3,   # use 10% (0.1) of the data for validation
    data_augmentation = False,
    save_best_model=True,
    model_path= data_dir + '/' + 'best_model.keras'
)
# Out:
# 📊 Shape of X_train: (520, 256, 256, 10)
# 📊 Shape of y_train: (520, 256, 256, 1)
# 🎯 Number of classes: 1
# ✅ Null values replaced with 0 in X and y
# ✅ Normalization applied band by band with StandardScaler
# Values in labels, min: 0 & max: 1
# ✅ Split: 364 training, 156 validation
# 📊 Final X_train shape: (364, 256, 256, 10)
# 📊 Final y_train shape: (364, 256, 256, 1)
# 📊 Final X_val shape: (156, 256, 256, 10)
# 📊 Final y_val shape: (156, 256, 256, 1)
# ✅ Model compiled successfully (monitor: val_mean_iou)
# 💾 Saving best model based on val_mean_iou (max)
# 🚀 Starting training...
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7548 - loss: 0.5991 - mean_iou: 0.3188
# Epoch 1: val_mean_iou improved from -inf to 0.43865, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - accuracy: 0.7612 - loss: 0.5900 - mean_iou: 0.3225 - val_accuracy: 0.9237 - val_loss: 0.2196 - val_mean_iou: 0.4386
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9228 - loss: 0.2354 - mean_iou: 0.4118
# Epoch 2: val_mean_iou improved from 0.43865 to 0.50235, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - accuracy: 0.9228 - loss: 0.2360 - mean_iou: 0.4143 - val_accuracy: 0.9413 - val_loss: 0.2000 - val_mean_iou: 0.5024
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9446 - loss: 0.1877 - mean_iou: 0.4941
# Epoch 3: val_mean_iou improved from 0.50235 to 0.60758, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.9448 - loss: 0.1872 - mean_iou: 0.4968 - val_accuracy: 0.9589 - val_loss: 0.1441 - val_mean_iou: 0.6076
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9487 - loss: 0.1547 - mean_iou: 0.6312
# Epoch 4: val_mean_iou improved from 0.60758 to 0.74658, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9488 - loss: 0.1540 - mean_iou: 0.6320 - val_accuracy: 0.9616 - val_loss: 0.1060 - val_mean_iou: 0.7466
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9385 - loss: 0.1645 - mean_iou: 0.6860
# Epoch 5: val_mean_iou improved from 0.74658 to 0.79364, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9387 - loss: 0.1644 - mean_iou: 0.6875 - val_accuracy: 0.9585 - val_loss: 0.1137 - val_mean_iou: 0.7936
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9557 - loss: 0.1261 - mean_iou: 0.7443
# Epoch 6: val_mean_iou did not improve from 0.79364
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9556 - loss: 0.1263 - mean_iou: 0.7436 - val_accuracy: 0.9592 - val_loss: 0.1105 - val_mean_iou: 0.7155
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9550 - loss: 0.1216 - mean_iou: 0.7482
# Epoch 7: val_mean_iou did not improve from 0.79364
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9549 - loss: 0.1218 - mean_iou: 0.7479 - val_accuracy: 0.9613 - val_loss: 0.1026 - val_mean_iou: 0.7850
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9564 - loss: 0.1166 - mean_iou: 0.7538
# Epoch 8: val_mean_iou did not improve from 0.79364
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9566 - loss: 0.1161 - mean_iou: 0.7527 - val_accuracy: 0.9672 - val_loss: 0.0883 - val_mean_iou: 0.7721
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9623 - loss: 0.1064 - mean_iou: 0.7627
# Epoch 9: val_mean_iou did not improve from 0.79364
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9623 - loss: 0.1063 - mean_iou: 0.7630 - val_accuracy: 0.9627 - val_loss: 0.1007 - val_mean_iou: 0.7636
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9537 - loss: 0.1262 - mean_iou: 0.7518
# Epoch 10: val_mean_iou improved from 0.79364 to 0.80414, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9541 - loss: 0.1252 - mean_iou: 0.7523 - val_accuracy: 0.9637 - val_loss: 0.1027 - val_mean_iou: 0.8041
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9575 - loss: 0.1144 - mean_iou: 0.7842
# Epoch 11: val_mean_iou did not improve from 0.80414
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9578 - loss: 0.1137 - mean_iou: 0.7843 - val_accuracy: 0.9690 - val_loss: 0.0828 - val_mean_iou: 0.7725
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9610 - loss: 0.1065 - mean_iou: 0.7584
# Epoch 12: val_mean_iou did not improve from 0.80414
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9612 - loss: 0.1059 - mean_iou: 0.7606 - val_accuracy: 0.9695 - val_loss: 0.0815 - val_mean_iou: 0.7999
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9614 - loss: 0.1087 - mean_iou: 0.7862
# Epoch 13: val_mean_iou improved from 0.80414 to 0.81668, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.9615 - loss: 0.1085 - mean_iou: 0.7846 - val_accuracy: 0.9664 - val_loss: 0.0916 - val_mean_iou: 0.8167
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9648 - loss: 0.0991 - mean_iou: 0.8174
# Epoch 14: val_mean_iou did not improve from 0.81668
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9648 - loss: 0.0993 - mean_iou: 0.8168 - val_accuracy: 0.9616 - val_loss: 0.1114 - val_mean_iou: 0.8051
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9638 - loss: 0.1047 - mean_iou: 0.7866
# Epoch 15: val_mean_iou did not improve from 0.81668
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9639 - loss: 0.1046 - mean_iou: 0.7885 - val_accuracy: 0.9705 - val_loss: 0.0801 - val_mean_iou: 0.7756
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9656 - loss: 0.0966 - mean_iou: 0.7546
# Epoch 16: val_mean_iou improved from 0.81668 to 0.82142, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - accuracy: 0.9656 - loss: 0.0966 - mean_iou: 0.7562 - val_accuracy: 0.9703 - val_loss: 0.0780 - val_mean_iou: 0.8214
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9678 - loss: 0.0864 - mean_iou: 0.8285
# Epoch 17: val_mean_iou improved from 0.82142 to 0.83179, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.9678 - loss: 0.0867 - mean_iou: 0.8275 - val_accuracy: 0.9717 - val_loss: 0.0791 - val_mean_iou: 0.8318
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9696 - loss: 0.0847 - mean_iou: 0.8180
# Epoch 18: val_mean_iou did not improve from 0.83179
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9692 - loss: 0.0855 - mean_iou: 0.8168 - val_accuracy: 0.9708 - val_loss: 0.0792 - val_mean_iou: 0.7815
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9680 - loss: 0.0888 - mean_iou: 0.7975
# Epoch 19: val_mean_iou did not improve from 0.83179
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9680 - loss: 0.0888 - mean_iou: 0.7986 - val_accuracy: 0.9706 - val_loss: 0.0777 - val_mean_iou: 0.8209
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9667 - loss: 0.0906 - mean_iou: 0.8185
# Epoch 20: val_mean_iou did not improve from 0.83179
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9668 - loss: 0.0902 - mean_iou: 0.8194 - val_accuracy: 0.9722 - val_loss: 0.0749 - val_mean_iou: 0.8288
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9711 - loss: 0.0790 - mean_iou: 0.8402
# Epoch 21: val_mean_iou improved from 0.83179 to 0.83345, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 311ms/step - accuracy: 0.9709 - loss: 0.0794 - mean_iou: 0.8392 - val_accuracy: 0.9733 - val_loss: 0.0736 - val_mean_iou: 0.8334
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9730 - loss: 0.0780 - mean_iou: 0.8451
# Epoch 22: val_mean_iou did not improve from 0.83345
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9728 - loss: 0.0783 - mean_iou: 0.8441 - val_accuracy: 0.9733 - val_loss: 0.0724 - val_mean_iou: 0.8163
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9686 - loss: 0.0861 - mean_iou: 0.8212
# Epoch 23: val_mean_iou improved from 0.83345 to 0.84050, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - accuracy: 0.9687 - loss: 0.0859 - mean_iou: 0.8221 - val_accuracy: 0.9724 - val_loss: 0.0776 - val_mean_iou: 0.8405
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9660 - loss: 0.0922 - mean_iou: 0.8552
# Epoch 24: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9661 - loss: 0.0920 - mean_iou: 0.8531 - val_accuracy: 0.9737 - val_loss: 0.0729 - val_mean_iou: 0.8343
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9664 - loss: 0.0946 - mean_iou: 0.8025
# Epoch 25: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9665 - loss: 0.0943 - mean_iou: 0.8036 - val_accuracy: 0.9721 - val_loss: 0.0750 - val_mean_iou: 0.7682
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9693 - loss: 0.0858 - mean_iou: 0.7472
# Epoch 26: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9693 - loss: 0.0857 - mean_iou: 0.7485 - val_accuracy: 0.9722 - val_loss: 0.0733 - val_mean_iou: 0.8140
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9696 - loss: 0.0820 - mean_iou: 0.8137
# Epoch 27: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9696 - loss: 0.0820 - mean_iou: 0.8127 - val_accuracy: 0.9724 - val_loss: 0.0804 - val_mean_iou: 0.8317
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9683 - loss: 0.0871 - mean_iou: 0.8129
# Epoch 28: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9684 - loss: 0.0869 - mean_iou: 0.8117 - val_accuracy: 0.9700 - val_loss: 0.0755 - val_mean_iou: 0.8222
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9657 - loss: 0.0934 - mean_iou: 0.7973
# Epoch 29: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9660 - loss: 0.0929 - mean_iou: 0.7962 - val_accuracy: 0.9732 - val_loss: 0.0728 - val_mean_iou: 0.8014
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9706 - loss: 0.0822 - mean_iou: 0.7954
# Epoch 30: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9707 - loss: 0.0822 - mean_iou: 0.7974 - val_accuracy: 0.9723 - val_loss: 0.0812 - val_mean_iou: 0.7877
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9698 - loss: 0.0849 - mean_iou: 0.7840
# Epoch 31: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9699 - loss: 0.0848 - mean_iou: 0.7868 - val_accuracy: 0.9723 - val_loss: 0.0723 - val_mean_iou: 0.8368
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9730 - loss: 0.0743 - mean_iou: 0.8519
# Epoch 32: val_mean_iou did not improve from 0.84050
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9729 - loss: 0.0745 - mean_iou: 0.8518 - val_accuracy: 0.9737 - val_loss: 0.0707 - val_mean_iou: 0.8262
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9698 - loss: 0.0823 - mean_iou: 0.8598
# Epoch 33: val_mean_iou improved from 0.84050 to 0.84990, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - accuracy: 0.9699 - loss: 0.0821 - mean_iou: 0.8596 - val_accuracy: 0.9734 - val_loss: 0.0729 - val_mean_iou: 0.8499
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9711 - loss: 0.0822 - mean_iou: 0.8457
# Epoch 34: val_mean_iou improved from 0.84990 to 0.85619, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - accuracy: 0.9711 - loss: 0.0819 - mean_iou: 0.8457 - val_accuracy: 0.9729 - val_loss: 0.0729 - val_mean_iou: 0.8562
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9712 - loss: 0.0802 - mean_iou: 0.8592
# Epoch 35: val_mean_iou did not improve from 0.85619
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9712 - loss: 0.0800 - mean_iou: 0.8589 - val_accuracy: 0.9726 - val_loss: 0.0712 - val_mean_iou: 0.8354
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9735 - loss: 0.0723 - mean_iou: 0.8677
# Epoch 36: val_mean_iou did not improve from 0.85619
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9735 - loss: 0.0723 - mean_iou: 0.8674 - val_accuracy: 0.9736 - val_loss: 0.0716 - val_mean_iou: 0.8507
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9741 - loss: 0.0723 - mean_iou: 0.8633
# Epoch 37: val_mean_iou did not improve from 0.85619
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9741 - loss: 0.0722 - mean_iou: 0.8631 - val_accuracy: 0.9731 - val_loss: 0.0715 - val_mean_iou: 0.8473
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9756 - loss: 0.0656 - mean_iou: 0.8629
# Epoch 38: val_mean_iou did not improve from 0.85619
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9754 - loss: 0.0662 - mean_iou: 0.8630 - val_accuracy: 0.9744 - val_loss: 0.0716 - val_mean_iou: 0.8449
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9741 - loss: 0.0731 - mean_iou: 0.8658
# Epoch 39: val_mean_iou did not improve from 0.85619
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9740 - loss: 0.0731 - mean_iou: 0.8659 - val_accuracy: 0.9739 - val_loss: 0.0697 - val_mean_iou: 0.8177
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9750 - loss: 0.0715 - mean_iou: 0.8802
# Epoch 40: val_mean_iou improved from 0.85619 to 0.85663, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9750 - loss: 0.0714 - mean_iou: 0.8790 - val_accuracy: 0.9717 - val_loss: 0.0771 - val_mean_iou: 0.8566
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9725 - loss: 0.0763 - mean_iou: 0.8614
# Epoch 41: val_mean_iou did not improve from 0.85663
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9726 - loss: 0.0759 - mean_iou: 0.8614 - val_accuracy: 0.9732 - val_loss: 0.0704 - val_mean_iou: 0.8512
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9763 - loss: 0.0659 - mean_iou: 0.8710
# Epoch 42: val_mean_iou did not improve from 0.85663
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9760 - loss: 0.0666 - mean_iou: 0.8698 - val_accuracy: 0.9712 - val_loss: 0.0775 - val_mean_iou: 0.8407
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9736 - loss: 0.0737 - mean_iou: 0.8622
# Epoch 43: val_mean_iou did not improve from 0.85663
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9735 - loss: 0.0739 - mean_iou: 0.8613 - val_accuracy: 0.9715 - val_loss: 0.0733 - val_mean_iou: 0.8038
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9701 - loss: 0.0799 - mean_iou: 0.8512
# Epoch 44: val_mean_iou did not improve from 0.85663
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9702 - loss: 0.0799 - mean_iou: 0.8504 - val_accuracy: 0.9726 - val_loss: 0.0752 - val_mean_iou: 0.8209
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9733 - loss: 0.0726 - mean_iou: 0.8689
# Epoch 45: val_mean_iou did not improve from 0.85663
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9733 - loss: 0.0727 - mean_iou: 0.8697 - val_accuracy: 0.9741 - val_loss: 0.0712 - val_mean_iou: 0.8388
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.9722 - loss: 0.0749 - mean_iou: 0.8560
# Epoch 46: val_mean_iou improved from 0.85663 to 0.86214, saving model to /content/drive/MyDrive/11_deepLearning//best_model.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.9722 - loss: 0.0748 - mean_iou: 0.8573 - val_accuracy: 0.9719 - val_loss: 0.0750 - val_mean_iou: 0.8621
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9726 - loss: 0.0742 - mean_iou: 0.8770
# Epoch 47: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9728 - loss: 0.0739 - mean_iou: 0.8757 - val_accuracy: 0.9748 - val_loss: 0.0679 - val_mean_iou: 0.8509
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9763 - loss: 0.0653 - mean_iou: 0.8800
# Epoch 48: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9762 - loss: 0.0655 - mean_iou: 0.8796 - val_accuracy: 0.9744 - val_loss: 0.0680 - val_mean_iou: 0.8392
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9756 - loss: 0.0665 - mean_iou: 0.8765
# Epoch 49: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9757 - loss: 0.0664 - mean_iou: 0.8775 - val_accuracy: 0.9745 - val_loss: 0.0697 - val_mean_iou: 0.8515
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9756 - loss: 0.0677 - mean_iou: 0.8950
# Epoch 50: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9756 - loss: 0.0674 - mean_iou: 0.8944 - val_accuracy: 0.9743 - val_loss: 0.0692 - val_mean_iou: 0.8368
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9764 - loss: 0.0647 - mean_iou: 0.8798
# Epoch 51: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9765 - loss: 0.0647 - mean_iou: 0.8787 - val_accuracy: 0.9728 - val_loss: 0.0728 - val_mean_iou: 0.8291
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9692 - loss: 0.0791 - mean_iou: 0.8297
# Epoch 52: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9692 - loss: 0.0795 - mean_iou: 0.8301 - val_accuracy: 0.9713 - val_loss: 0.0788 - val_mean_iou: 0.7759
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9684 - loss: 0.0881 - mean_iou: 0.7128
# Epoch 53: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9684 - loss: 0.0880 - mean_iou: 0.7153 - val_accuracy: 0.9721 - val_loss: 0.0753 - val_mean_iou: 0.8067
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9725 - loss: 0.0775 - mean_iou: 0.8136
# Epoch 54: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9725 - loss: 0.0776 - mean_iou: 0.8141 - val_accuracy: 0.9734 - val_loss: 0.0715 - val_mean_iou: 0.8080
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9753 - loss: 0.0691 - mean_iou: 0.8328
# Epoch 55: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9753 - loss: 0.0689 - mean_iou: 0.8341 - val_accuracy: 0.9734 - val_loss: 0.0732 - val_mean_iou: 0.8486
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9779 - loss: 0.0614 - mean_iou: 0.8792
# Epoch 56: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9777 - loss: 0.0616 - mean_iou: 0.8777 - val_accuracy: 0.9744 - val_loss: 0.0681 - val_mean_iou: 0.8472
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9811 - loss: 0.0536 - mean_iou: 0.9023
# Epoch 57: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9808 - loss: 0.0542 - mean_iou: 0.9005 - val_accuracy: 0.9735 - val_loss: 0.0696 - val_mean_iou: 0.8336
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9782 - loss: 0.0585 - mean_iou: 0.8845
# Epoch 58: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9781 - loss: 0.0586 - mean_iou: 0.8835 - val_accuracy: 0.9744 - val_loss: 0.0708 - val_mean_iou: 0.8441
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9797 - loss: 0.0552 - mean_iou: 0.8928
# Epoch 59: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9796 - loss: 0.0555 - mean_iou: 0.8927 - val_accuracy: 0.9745 - val_loss: 0.0698 - val_mean_iou: 0.8362
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9784 - loss: 0.0586 - mean_iou: 0.8746
# Epoch 60: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9784 - loss: 0.0586 - mean_iou: 0.8753 - val_accuracy: 0.9731 - val_loss: 0.0745 - val_mean_iou: 0.8511
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9780 - loss: 0.0625 - mean_iou: 0.8651
# Epoch 61: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9779 - loss: 0.0625 - mean_iou: 0.8657 - val_accuracy: 0.9740 - val_loss: 0.0706 - val_mean_iou: 0.8485
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9785 - loss: 0.0604 - mean_iou: 0.8936
# Epoch 62: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9785 - loss: 0.0602 - mean_iou: 0.8938 - val_accuracy: 0.9746 - val_loss: 0.0699 - val_mean_iou: 0.8423
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9784 - loss: 0.0596 - mean_iou: 0.9048
# Epoch 63: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9784 - loss: 0.0593 - mean_iou: 0.9037 - val_accuracy: 0.9738 - val_loss: 0.0745 - val_mean_iou: 0.8358
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9822 - loss: 0.0488 - mean_iou: 0.9061
# Epoch 64: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9820 - loss: 0.0493 - mean_iou: 0.9051 - val_accuracy: 0.9741 - val_loss: 0.0699 - val_mean_iou: 0.8239
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9795 - loss: 0.0567 - mean_iou: 0.8662
# Epoch 65: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9796 - loss: 0.0565 - mean_iou: 0.8681 - val_accuracy: 0.9732 - val_loss: 0.0743 - val_mean_iou: 0.8348
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9807 - loss: 0.0522 - mean_iou: 0.8945
# Epoch 66: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9806 - loss: 0.0523 - mean_iou: 0.8955 - val_accuracy: 0.9740 - val_loss: 0.0732 - val_mean_iou: 0.8278
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9808 - loss: 0.0518 - mean_iou: 0.9015
# Epoch 67: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9808 - loss: 0.0517 - mean_iou: 0.9017 - val_accuracy: 0.9747 - val_loss: 0.0745 - val_mean_iou: 0.8334
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9816 - loss: 0.0493 - mean_iou: 0.9097
# Epoch 68: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9815 - loss: 0.0493 - mean_iou: 0.9092 - val_accuracy: 0.9735 - val_loss: 0.0732 - val_mean_iou: 0.8237
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9780 - loss: 0.0662 - mean_iou: 0.8796
# Epoch 69: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9775 - loss: 0.0683 - mean_iou: 0.8774 - val_accuracy: 0.9646 - val_loss: 0.1102 - val_mean_iou: 0.6403
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9594 - loss: 0.1284 - mean_iou: 0.7619
# Epoch 70: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9597 - loss: 0.1272 - mean_iou: 0.7644 - val_accuracy: 0.9694 - val_loss: 0.0828 - val_mean_iou: 0.8205
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9682 - loss: 0.0905 - mean_iou: 0.7976
# Epoch 71: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9682 - loss: 0.0902 - mean_iou: 0.7984 - val_accuracy: 0.9705 - val_loss: 0.0795 - val_mean_iou: 0.8304
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9717 - loss: 0.0791 - mean_iou: 0.8376
# Epoch 72: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9719 - loss: 0.0787 - mean_iou: 0.8382 - val_accuracy: 0.9730 - val_loss: 0.0736 - val_mean_iou: 0.8256
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9748 - loss: 0.0677 - mean_iou: 0.8561
# Epoch 73: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9749 - loss: 0.0678 - mean_iou: 0.8568 - val_accuracy: 0.9727 - val_loss: 0.0769 - val_mean_iou: 0.8372
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9771 - loss: 0.0650 - mean_iou: 0.8795
# Epoch 74: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9771 - loss: 0.0650 - mean_iou: 0.8780 - val_accuracy: 0.9711 - val_loss: 0.0780 - val_mean_iou: 0.8037
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9795 - loss: 0.0566 - mean_iou: 0.8827
# Epoch 75: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9795 - loss: 0.0567 - mean_iou: 0.8835 - val_accuracy: 0.9737 - val_loss: 0.0725 - val_mean_iou: 0.8272
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9801 - loss: 0.0551 - mean_iou: 0.8945
# Epoch 76: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9801 - loss: 0.0550 - mean_iou: 0.8953 - val_accuracy: 0.9726 - val_loss: 0.0766 - val_mean_iou: 0.8236
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9817 - loss: 0.0512 - mean_iou: 0.9009
# Epoch 77: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9817 - loss: 0.0513 - mean_iou: 0.9014 - val_accuracy: 0.9726 - val_loss: 0.0879 - val_mean_iou: 0.8466
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9828 - loss: 0.0481 - mean_iou: 0.8885
# Epoch 78: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9826 - loss: 0.0485 - mean_iou: 0.8886 - val_accuracy: 0.9735 - val_loss: 0.0741 - val_mean_iou: 0.8445
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9834 - loss: 0.0455 - mean_iou: 0.9133
# Epoch 79: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9833 - loss: 0.0457 - mean_iou: 0.9136 - val_accuracy: 0.9728 - val_loss: 0.0776 - val_mean_iou: 0.8373
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9837 - loss: 0.0450 - mean_iou: 0.9088
# Epoch 80: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9837 - loss: 0.0450 - mean_iou: 0.9095 - val_accuracy: 0.9732 - val_loss: 0.0798 - val_mean_iou: 0.8457
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9847 - loss: 0.0416 - mean_iou: 0.9378
# Epoch 81: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9846 - loss: 0.0417 - mean_iou: 0.9373 - val_accuracy: 0.9723 - val_loss: 0.0917 - val_mean_iou: 0.8453
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9853 - loss: 0.0399 - mean_iou: 0.9134
# Epoch 82: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9852 - loss: 0.0401 - mean_iou: 0.9139 - val_accuracy: 0.9726 - val_loss: 0.0892 - val_mean_iou: 0.8463
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9837 - loss: 0.0436 - mean_iou: 0.9136
# Epoch 83: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9838 - loss: 0.0434 - mean_iou: 0.9136 - val_accuracy: 0.9727 - val_loss: 0.0893 - val_mean_iou: 0.8422
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9843 - loss: 0.0423 - mean_iou: 0.9296
# Epoch 84: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9844 - loss: 0.0420 - mean_iou: 0.9288 - val_accuracy: 0.9718 - val_loss: 0.0964 - val_mean_iou: 0.8464
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9850 - loss: 0.0406 - mean_iou: 0.9235
# Epoch 85: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9851 - loss: 0.0403 - mean_iou: 0.9235 - val_accuracy: 0.9713 - val_loss: 0.1013 - val_mean_iou: 0.8423
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9867 - loss: 0.0353 - mean_iou: 0.9340
# Epoch 86: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9867 - loss: 0.0354 - mean_iou: 0.9331 - val_accuracy: 0.9728 - val_loss: 0.0922 - val_mean_iou: 0.8477
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9865 - loss: 0.0360 - mean_iou: 0.9354
# Epoch 87: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9866 - loss: 0.0360 - mean_iou: 0.9354 - val_accuracy: 0.9722 - val_loss: 0.0935 - val_mean_iou: 0.8463
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9873 - loss: 0.0337 - mean_iou: 0.9253
# Epoch 88: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9873 - loss: 0.0339 - mean_iou: 0.9249 - val_accuracy: 0.9718 - val_loss: 0.0980 - val_mean_iou: 0.8352
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9879 - loss: 0.0320 - mean_iou: 0.9360
# Epoch 89: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9879 - loss: 0.0321 - mean_iou: 0.9361 - val_accuracy: 0.9717 - val_loss: 0.1032 - val_mean_iou: 0.8394
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9889 - loss: 0.0293 - mean_iou: 0.9403
# Epoch 90: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9889 - loss: 0.0295 - mean_iou: 0.9393 - val_accuracy: 0.9720 - val_loss: 0.1104 - val_mean_iou: 0.8368
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9888 - loss: 0.0295 - mean_iou: 0.9423
# Epoch 91: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9888 - loss: 0.0296 - mean_iou: 0.9419 - val_accuracy: 0.9719 - val_loss: 0.1056 - val_mean_iou: 0.8521
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9895 - loss: 0.0273 - mean_iou: 0.9451
# Epoch 92: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9894 - loss: 0.0274 - mean_iou: 0.9449 - val_accuracy: 0.9717 - val_loss: 0.1045 - val_mean_iou: 0.8396
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9891 - loss: 0.0289 - mean_iou: 0.9528
# Epoch 93: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9891 - loss: 0.0288 - mean_iou: 0.9527 - val_accuracy: 0.9727 - val_loss: 0.1119 - val_mean_iou: 0.8421
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9894 - loss: 0.0277 - mean_iou: 0.9426
# Epoch 94: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - accuracy: 0.9894 - loss: 0.0277 - mean_iou: 0.9430 - val_accuracy: 0.9727 - val_loss: 0.1104 - val_mean_iou: 0.8378
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9895 - loss: 0.0274 - mean_iou: 0.9472
# Epoch 95: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9895 - loss: 0.0273 - mean_iou: 0.9472 - val_accuracy: 0.9721 - val_loss: 0.1094 - val_mean_iou: 0.8466
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9895 - loss: 0.0271 - mean_iou: 0.9452
# Epoch 96: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 185ms/step - accuracy: 0.9895 - loss: 0.0271 - mean_iou: 0.9459 - val_accuracy: 0.9706 - val_loss: 0.1086 - val_mean_iou: 0.8306
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9887 - loss: 0.0303 - mean_iou: 0.9443
# Epoch 97: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9886 - loss: 0.0306 - mean_iou: 0.9434 - val_accuracy: 0.9711 - val_loss: 0.1060 - val_mean_iou: 0.8152
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9888 - loss: 0.0305 - mean_iou: 0.9266
# Epoch 98: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 183ms/step - accuracy: 0.9887 - loss: 0.0306 - mean_iou: 0.9269 - val_accuracy: 0.9718 - val_loss: 0.1024 - val_mean_iou: 0.8181
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9880 - loss: 0.0313 - mean_iou: 0.9483
# Epoch 99: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9881 - loss: 0.0312 - mean_iou: 0.9474 - val_accuracy: 0.9720 - val_loss: 0.0930 - val_mean_iou: 0.8170
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9896 - loss: 0.0280 - mean_iou: 0.9053
# Epoch 100: val_mean_iou did not improve from 0.86214
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 184ms/step - accuracy: 0.9896 - loss: 0.0281 - mean_iou: 0.9052 - val_accuracy: 0.9717 - val_loss: 0.1097 - val_mean_iou: 0.8296

# %%
# Print the available metrics and losses stored during training
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'mean_iou', 'val_accuracy', 'val_loss', 'val_mean_iou'])

# %% [markdown]
# This plot shows the training and validation performance of the U-Net model across epochs. The left panel illustrates the evolution of the loss function for both training and validation, which helps monitor overfitting or underfitting. The right panel displays the Mean IoU (Intersection over Union), a key segmentation metric, for training and validation, providing insights into how well the model learns to segment satellite images over time.

# %%
hist = history.history
epochs = range(1, len(hist['loss']) + 1)

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# --- Loss ---
ax[0].plot(epochs, hist['loss'], label='Training')
ax[0].plot(epochs, hist['val_loss'], label='Validation')
ax[0].set_title("Loss")
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Loss")
ax[0].legend()

# --- IoU ---
ax[1].plot(epochs, hist['mean_iou'], label='Training')
ax[1].plot(epochs, hist['val_mean_iou'], label='Validation')
ax[1].set_title("Mean IoU")
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("IoU")
ax[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Full prediction**
#
# In this step, we will predict on a new raster image using the trained U-Net model. Inside the `predictRaster()` function, the `processing()` function is used to divide the input raster into patches. After prediction, the patches are reconstructed back into a full raster mosaic with the same size and extent as the original image.
#
# **Key arguments**:
# - `raster_path`: Path to the input raster image (different from the training set or similar).
# - `patch_size`: Patch size used for prediction (must match training).
# - `num_classes`: Number of output classes (same as training).
# - `output_path`: Path to save the predicted raster (optional).
# - `fill_nulls`: If `True`, replaces null values with the value set in `null_value`.
# - `null_value`: Value used to replace missing or infinite values.
# - `normalize`: If `True`, applies the same normalization as during training.
# - `overlap`: Number of pixels to overlap between patches, useful for smoothing predictions.

# %%
# Step 3: Perform full prediction
prediction = predictRaster(
    model = model,
    raster_path = data_dir + '/' + 'S2_Tile29.tif',
    patch_size = 256,  # Same as used during training
    num_classes = 1,   # Same as used during training
    output_path = data_dir + '/' + 'final_prediction.tif',  # Optional: save result
    fill_nulls = True,
    null_value = 0,
    normalize = True,
    overlap = 0,
)
# Out:
# Processing file: /content/drive/MyDrive/11_deepLearning//S2_Tile29.tif
# Handling null values...
# ✅ Normalization applied to X
# Running prediction...
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 337ms/step
# Predicted classes: [0 1]
# Prediction saved at: /content/drive/MyDrive/11_deepLearning//final_prediction.tif

# %% [markdown]
# Here we visualize the predicted burned area map alongside the NRBR index raster used as input for the model. This side-by-side comparison allows us to evaluate how the predicted segmentation relates to the original spectral information from the satellite image.

# %%
fig, ax = plt.subplots(1, 2, figsize = (12,6))

plotRGB(img_test, bands = [10, 7, 3], title = 'Testing: NRBR - Tile29', ax = ax[0])
ax[1].imshow(prediction,cmap = reversed_map)
ax[1].set_title('Prediction on the whole image')
plt.show()

# %% [markdown]
# ## 4.0 Accuracy assessment

# %%
# 2. Load reference labels

# Tile29: Reference data
path_raster_label_test = data_dir + "Label_Tile29.tif"
label_test = rasterio.open(path_raster_label_test).read(1)
label_test[np.isnan(label_test)] = 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (12,6))

ax[0].imshow(prediction,cmap = reversed_map)
ax[0].set_title('Prediction on the whole image')
ax[1].imshow(label_test,cmap = reversed_map)
ax[1].set_title('Reference data')
plt.show()

# %%
# 3. Evaluate
results = evaluateSegmentation(y_true_array = label_test,
                               y_pred_array = prediction,
                               num_classes=2,
                               classes=['unburned', 'burned'])
# Out:
# ========================== Accuracy Metrics ================================
# ✅ Evaluation completed. Metrics below are averaged across all classes.
# 📊 Overall Accuracy (all classes): 0.9307
# 📊 Precision (weighted): 0.9362
# 📊 Recall (weighted): 0.9307
# 📊 F1-score (weighted): 0.9308
# 📊 IoU (weighted): 0.8705
# 📊 Dice Coefficient (macro): 0.9306
#
#
#
# Confusion matrix:
